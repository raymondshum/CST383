# %% [markdown]
# STUDENT NAME: Raymond Shum
#
# CLASS: CST383-30_SP22
#
# ASSIGNMENT: Week 7 - Lab 1
#
# DUE DATE: Feb. 22, 2022

# %% [markdown]
# #### 1. Explain why decision trees are non parametric models.
#
# We do not see or know the parameters or boundaries of the model before we see the training data.

# %% [markdown]
# #### 2.	Create a Python file.  Use this code to read and preprocess the data.  (see number 7 for how to install graphviz)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split
import graphviz

df = pd.read_csv('https://raw.githubusercontent.com/grbruns/cst383/master/College.csv', index_col=0)

# %% [markdown]
# #### 3.	Convert the 'Private' column to an numeric column with values 0 and 1 (1 for private colleges).

# %%
df['Private'] = (df['Private'] == 'Yes').values.astype(int)

# %% [markdown]
# #### 4.	Do a little exploration of the data to remember what it’s like.  E.g., use df.info(), df.describe().

# %%
# No null, all integers
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    int32
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    float64
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
#  17  Grad.Rate    777 non-null    int64
# ...

# %%
df.describe()
# Out:
#           Private          Apps        Accept       Enroll   Top10perc  \
# count  777.000000    777.000000    777.000000   777.000000  777.000000
# mean     0.727156   3001.638353   2018.804376   779.972973   27.558559
# std      0.445708   3870.201484   2451.113971   929.176190   17.640364
# min      0.000000     81.000000     72.000000    35.000000    1.000000
# 25%      0.000000    776.000000    604.000000   242.000000   15.000000
# 50%      1.000000   1558.000000   1110.000000   434.000000   23.000000
# 75%      1.000000   3624.000000   2424.000000   902.000000   35.000000
# max      1.000000  48094.000000  26330.000000  6392.000000   96.000000
#
#         Top25perc   F.Undergrad   P.Undergrad      Outstate   Room.Board  \
# count  777.000000    777.000000    777.000000    777.000000   777.000000
# mean    55.796654   3699.907336    855.298584  10440.669241  4357.526384
# std     19.804778   4850.420531   1522.431887   4023.016484  1096.696416
# ...

# %%
df.hist();

# %%
# Which values are most highly correlated?
sns.heatmap(data=df.drop(columns=["Private"]).corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 5.	We will try to predict whether a college is public or private.  Select a few predictors, create NumPy arrays X and y, and then do a training/test split.  Try hard to remember how to do this from memory.  If you can't, refer to the hints.

# %%
target = 'Private'
predictors = ['Enroll', 'Outstate', 'perc.alumni', 'Grad.Rate']

y=df[target]
X=df[predictors]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# %% [markdown]
# #### 6.	Train a tree classifier using Scikit-Learn's DecisionTreeClassifier.  Use the training data you created in the previous step.

# %%
clf = DecisionTreeClassifier(max_depth=5, random_state=0)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=0)

# %% [markdown]
# #### 7.	Install graphviz by entering conda install python-graphviz at the Anaconda prompt.  Then plot your tree using graphviz.  Try playing with some of the options of export_graphviz().

# %%
# Installed using conda prompt

# %% [markdown]
# #### 8.	Use your classification tree to predict whether examples in your test data are public or private.  Compute the confusion matrix and the accuracy of your predictions..

# %%
target_names = ['Public', 'Private']
dot_data = export_graphviz(clf, precision=2,
                          feature_names=predictors,
                          class_names=target_names,
                          filled=True,
                          rounded=True,
                          special_characters=True)

graph = graphviz.Source(dot_data)
graph

# %%
y_predict = clf.predict(X_test)

(y_predict == y_test).mean().round(2)
# Out:
# 0.93

# %% [markdown]
# #### 9.	If you still have time, do the following:
# - try building more classification trees, using different sets of input features
# - look at, and play with, the hyperparameters available in DecisionTreeClassifier, especially max_depth.
# - see how much the classification tree that you produce depends on your particular training set

# %%
# Features don't get used unless there's sufficient depth
# Consider using argsort in the futre
print('Feature Importances:')
for i, feature in enumerate(clf.feature_importances_):
    print(f'  {predictors[i]}: {feature:.3f}')
# Out:
# Feature Importances:
#   Enroll: 0.397
#   Outstate: 0.548
#   perc.alumni: 0.003
#   Grad.Rate: 0.051

# %%
# New predictions with Outstate and Grad. Rate (I did worse this way):
target = 'Private'
predictors = ['Outstate', 'Grad.Rate']

y=df[target]
X=df[predictors]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)
clf = DecisionTreeClassifier(max_depth=2, random_state=0)
clf.fit(X_train, y_train)

y_predict = clf.predict(X_test)
(y_predict == y_test).mean().round(2)
# Out:
# 0.86
